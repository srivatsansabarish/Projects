# %% [markdown]
# #### Database of 10k rows with random data for users.
#
# #### Objective : To show users most relevant posts at the top, basis his past interaction with the app.
# #### Relevant post : The post he is most likely to interact with.
# Step 1 : Determine input variables like upvote, downvote, time spent on post, etc.(Use the app to find out more input variables) by a user for every post
#
# Step 2 : Populate these variables with random data for each of the user
#
# Step 3 : Based on the analysis of the data, create a mathematical formula to rank each post (Top ranked most will be shown to the user at first )

# %% [markdown]
# #### The columns we created [ "User_ID" , "upvote" , "downvote" , "comments" , "impressions" , "followers" , "timespent" , "age" , "gender" , "clan" , "rank" ]

# %% [markdown]
# #### User_ID-
# It is the unique ID given to each user on the app
#
# #### upvote-
# It is the number of users who have liked or given positive response to the post [Random distribution]
#
# #### downvote-
# It is the number of users who have disliked or given negative response to the post[Random distribution]
#
# #### comments-
# It is the total number of comments for a post by various users[assuming it to be 10 percent of the sum of upvotes and downvotes]
#
# #### impressions-
# It is the total number of times the post has been seen by various users[assuming it to be 150 percent of the sum of upvotes and downvotes]
#
# #### followers-
# It is the total number of users following a particular user [assuming it to be 5 times the number of impressions]
# #### Viewers-
# It Is total number of people who have viewed the post but have not upvoted or downvoted[assuming it to be (impressions-upvote+downvote)
#
# #### timespent-
# It is total time spent by various users on a single post[Assuming time consumed for upvote and downvote to be 15 seconds,comments-30seconds and viewers-10 seconds]
#
# #### age-
# It is the age of each user[Random distribution]
#
# #### gender-
# the gender of each user whether it is male or female
#
# #### clan-
# The community to which the post is posted which might be cricket,politics or anything.
#
# #### rank_value-
# this is total value for each post which is given by the formula upvote-downvote+comments+impressions
# #### Rank-
# Based on the rank_value we have ranked each post and the order of which the post is shown in the app.

# %%
import numpy as np
import pandas as pd

# %%
column_names=["User_ID","upvote","downvote","comments","impressions","followers","timespent","age","gender","clan","rank"]
data=pd.DataFrame(index=range(1,10001),columns=column_names)

# %%
data.head()
# Out:
#   User_ID upvote downvote comments impressions followers timespent  age  \
# 1     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 2     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 3     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 4     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 5     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
data.shape
# Out:
# (10000, 11)

# %%
for i in range(1,10001):
    data["User_ID"][i]=i

# %%
data.head()
# Out:
#   User_ID upvote downvote comments impressions followers timespent  age  \
# 1       1    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 2       2    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 3       3    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 4       4    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 5       5    NaN      NaN      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
import random
data["upvote"]=data["upvote"].apply(lambda x:np.random.random()*1000)

# %%
data["upvote"]=data["upvote"].apply(np.floor)

# %%
data.head()
# Out:
#   User_ID  upvote downvote comments impressions followers timespent  age  \
# 1       1   200.0      NaN      NaN         NaN       NaN       NaN  NaN
# 2       2   569.0      NaN      NaN         NaN       NaN       NaN  NaN
# 3       3   677.0      NaN      NaN         NaN       NaN       NaN  NaN
# 4       4   630.0      NaN      NaN         NaN       NaN       NaN  NaN
# 5       5   927.0      NaN      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
import random
data["downvote"]=data["downvote"].apply(lambda x:np.random.random()*1000)

# %%
data["downvote"]=data["downvote"].round(decimals=0)

# %%
data.head()
# Out:
#   User_ID  upvote  downvote comments impressions followers timespent  age  \
# 1       1   200.0     330.0      NaN         NaN       NaN       NaN  NaN
# 2       2   569.0     430.0      NaN         NaN       NaN       NaN  NaN
# 3       3   677.0     317.0      NaN         NaN       NaN       NaN  NaN
# 4       4   630.0     407.0      NaN         NaN       NaN       NaN  NaN
# 5       5   927.0     890.0      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
data.describe()
# Out:
#              upvote      downvote
# count  10000.000000  10000.000000
# mean     501.511700    499.544900
# std      288.272429    288.085159
# min        0.000000      0.000000
# 25%      251.000000    251.000000
# 50%      501.000000    495.000000
# 75%      754.000000    749.000000
# max      999.000000   1000.000000

# %% [markdown]
# #### As the data are completely random we went with many assumptions. Here we assume that comments are nearly 1/10 of the total users who reacted to that post
#
# #### Comments=[ (Upvote + Downvote) / 10 ]

# %%
data["comments"]=(data["upvote"]+data["downvote"])/10

# %%
data["comments"]=data["comments"].apply(np.floor)

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments impressions followers timespent  age  \
# 1       1   200.0     330.0      53.0         NaN       NaN       NaN  NaN
# 2       2   569.0     430.0      99.0         NaN       NaN       NaN  NaN
# 3       3   677.0     317.0      99.0         NaN       NaN       NaN  NaN
# 4       4   630.0     407.0     103.0         NaN       NaN       NaN  NaN
# 5       5   927.0     890.0     181.0         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments impressions followers timespent  age  \
# 1       1   200.0     330.0      53.0         NaN       NaN       NaN  NaN
# 2       2   569.0     430.0      99.0         NaN       NaN       NaN  NaN
# 3       3   677.0     317.0      99.0         NaN       NaN       NaN  NaN
# 4       4   630.0     407.0     103.0         NaN       NaN       NaN  NaN
# 5       5   927.0     890.0     181.0         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %% [markdown]
# #### And generally for every post not all of them will react so we assumed that total impressions are nearly 1.5 times the total users who reacted to that post

# %%
data["impressions"]=(data["upvote"]+data["downvote"])*1.5

# %%
data["impressions"]=data["impressions"].apply(np.floor)

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions followers timespent  age  \
# 1       1   200.0     330.0      53.0        795.0       NaN       NaN  NaN
# 2       2   569.0     430.0      99.0       1498.0       NaN       NaN  NaN
# 3       3   677.0     317.0      99.0       1491.0       NaN       NaN  NaN
# 4       4   630.0     407.0     103.0       1555.0       NaN       NaN  NaN
# 5       5   927.0     890.0     181.0       2725.0       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %% [markdown]
# #### And same for followers, Not every followers will react to a particular post.
# #### E.g: If a user has 1 million followers not all of them will see or react to the post due to various reasons like not using the app much enough or a particular user may miss his/her follower's post. So we gave the total followers as 5 times the impressions.
#
# #### Followers= Impressions*5

# %%
data["followers"]=data["impressions"]*5

# %%
data["followers"]=data["followers"].apply(np.floor)

# %%
data["age"]=data["age"].apply(lambda x:np.random.randint(20,50))

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0       NaN   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0       NaN   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0       NaN   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0       NaN   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0       NaN   39
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %% [markdown]
# #### We just randomize the gender column

# %%
data["gender"]=data["gender"].apply(lambda x:np.random.randint(1,3))

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0       NaN   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0       NaN   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0       NaN   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0       NaN   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0       NaN   39
#
#    gender clan rank
# 1       1  NaN  NaN
# 2       2  NaN  NaN
# 3       1  NaN  NaN
# 4       1  NaN  NaN
# 5       2  NaN  NaN

# %%
data["gender"].value_counts()
# Out:
# 1    5009
# 2    4991
# Name: gender, dtype: int64

# %%
data["gender"]=data["gender"].replace({1:"Male",2:"Female"})

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0       NaN   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0       NaN   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0       NaN   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0       NaN   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0       NaN   39
#
#    gender clan rank
# 1    Male  NaN  NaN
# 2  Female  NaN  NaN
# 3    Male  NaN  NaN
# 4    Male  NaN  NaN
# 5  Female  NaN  NaN

# %%
data["viewers"]=((data["impressions"])-(data["upvote"]+data["downvote"]))

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0       NaN   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0       NaN   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0       NaN   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0       NaN   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0       NaN   39
#
#    gender clan rank  viewers
# 1    Male  NaN  NaN    265.0
# 2  Female  NaN  NaN    499.0
# 3    Male  NaN  NaN    497.0
# 4    Male  NaN  NaN    518.0
# 5  Female  NaN  NaN    908.0

# %% [markdown]
# #### Timespent-It is total time spent by various users on a single post[Assuming time consumed for upvote and downvote to be 15 seconds,comments-30seconds and viewers-10 seconds]

# %%
data["timespent"]=((data["upvote"]+data["downvote"])*15+(data["comments"]*30)+(data["viewers"]*10))

# %%
data["timespent"]=data["timespent"]/3600

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers  timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0   3.386111   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0   6.373611   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0   6.347222   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0   6.618056   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0  11.601389   39
#
#    gender clan rank  viewers
# 1    Male  NaN  NaN    265.0
# 2  Female  NaN  NaN    499.0
# 3    Male  NaN  NaN    497.0
# 4    Male  NaN  NaN    518.0
# 5  Female  NaN  NaN    908.0

# %%
data["clan"]=data["clan"].apply(lambda x:np.random.randint(1,14))

# %%
data["clan"].value_counts()
# Out:
# 2     839
# 9     833
# 5     802
# 10    788
# 11    784
# 8     770
# 4     761
# 6     746
# 13    743
# 1     738
# 3     735
# 7     734
# 12    727
# Name: clan, dtype: int64

# %% [markdown]
# ### The clans we used here for the particular post are:
# 1:"Technology"
#
# 2:"Travel"
#
# 3:"Internships"
#
# 4:"Jobs
#
# 5:"Startups"
#
# 6:"Trending"
#
# 7:"Fashion"
#
# 8:"Politics"
#
# 9:"Music"
#
# 10:"Bollywood"
#
# 11:"Cricket"
#
# 12:"News"
#
# 13:"Food"

# %%
data["clan"]=data["clan"].replace({1:"Technology",2:"Travel",3:"Internships",4:"Jobs",5:"Startups",6:"Trending",7:"Fashion",8:"Politics",9:"Music",10:"Bollywood",11:"Cricket",12:"News",13:"Food"})

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers  timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0   3.386111   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0   6.373611   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0   6.347222   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0   6.618056   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0  11.601389   39
#
#    gender         clan rank  viewers
# 1    Male       Travel  NaN    265.0
# 2  Female       Travel  NaN    499.0
# 3    Male    Bollywood  NaN    497.0
# 4    Male    Bollywood  NaN    518.0
# 5  Female  Internships  NaN    908.0

# %%
data["clan"].value_counts()
# Out:
# Travel         839
# Music          833
# Startups       802
# Bollywood      788
# Cricket        784
# Politics       770
# Jobs           761
# Trending       746
# Food           743
# Technology     738
# Internships    735
# Fashion        734
# News           727
# Name: clan, dtype: int64

# %% [markdown]
# #### Just for the calculations we used viewers column

# %%
data.drop("viewers",axis=1,inplace=True)

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers  timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0   3.386111   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0   6.373611   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0   6.347222   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0   6.618056   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0  11.601389   39
#
#    gender         clan rank
# 1    Male       Travel  NaN
# 2  Female       Travel  NaN
# 3    Male    Bollywood  NaN
# 4    Male    Bollywood  NaN
# 5  Female  Internships  NaN

# %% [markdown]
# #### To get the Rank for each post we need to use some mathematical formula to calculate the each post.
#
# #### Rank value= Upvote - Downvote + impressions + comments
#
# #### The reason behind subtracting Downvotes from Upvotes is to show the Post with upvotes at the top not with highest downvotes and also based on the previous impressions and followers it tries to show the popular post first.

# %%
data["Rank_value"]=data["upvote"]-data["downvote"]+data["impressions"]+data["comments"]

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers  timespent  age  \
# 1       1   200.0     330.0      53.0        795.0     3975.0   3.386111   26
# 2       2   569.0     430.0      99.0       1498.0     7490.0   6.373611   42
# 3       3   677.0     317.0      99.0       1491.0     7455.0   6.347222   46
# 4       4   630.0     407.0     103.0       1555.0     7775.0   6.618056   40
# 5       5   927.0     890.0     181.0       2725.0    13625.0  11.601389   39
#
#    gender         clan rank  Rank_value
# 1    Male       Travel  NaN       718.0
# 2  Female       Travel  NaN      1736.0
# 3    Male    Bollywood  NaN      1950.0
# 4    Male    Bollywood  NaN      1881.0
# 5  Female  Internships  NaN      2943.0

# %%
data["rank"]=data["Rank_value"].rank(ascending=0)

# %%
data=data.sort_values("rank",ascending=True)

# %%
data.head(5)
# Out:
#      User_ID  upvote  downvote  comments  impressions  followers  timespent  \
# 8594    8594   991.0     983.0     197.0       2961.0    14805.0  12.608333
# 3284    3284   997.0     952.0     194.0       2923.0    14615.0  12.443056
# 3699    3699   989.0     981.0     197.0       2955.0    14775.0  12.586111
# 8274    8274   996.0     952.0     194.0       2922.0    14610.0  12.438889
# 7286    7286   991.0     954.0     194.0       2917.0    14585.0  12.420833
#
#       age  gender       clan  rank  Rank_value
# 8594   23  Female       News   1.0      3166.0
# 3284   21  Female      Music   2.0      3162.0
# 3699   29  Female  Bollywood   3.5      3160.0
# 8274   28  Female    Fashion   3.5      3160.0
# 7286   48    Male     Travel   5.5      3148.0

# %%
data.drop("Rank_value",axis=1,inplace=True)

# %% [markdown]
# ### Top 20 posts

# %%
data.head(20)
# Out:
#      User_ID  upvote  downvote  comments  impressions  followers  timespent  \
# 8594    8594   991.0     983.0     197.0       2961.0    14805.0  12.608333
# 3284    3284   997.0     952.0     194.0       2923.0    14615.0  12.443056
# 3699    3699   989.0     981.0     197.0       2955.0    14775.0  12.586111
# 8274    8274   996.0     952.0     194.0       2922.0    14610.0  12.438889
# 7286    7286   991.0     954.0     194.0       2917.0    14585.0  12.420833
# 2249    2249   995.0     935.0     193.0       2895.0    14475.0  12.330556
# 1538    1538   979.0     999.0     197.0       2967.0    14835.0  12.630556
# 6609    6609   981.0     972.0     195.0       2929.0    14645.0  12.473611
# 9303    9303   978.0     982.0     196.0       2940.0    14700.0  12.522222
# 2649    2649   979.0     974.0     195.0       2929.0    14645.0  12.473611
# 2200    2200   983.0     953.0     193.0       2904.0    14520.0  12.363889
# 8126    8126   987.0     933.0     192.0       2880.0    14400.0  12.266667
# 5515    5515   992.0     909.0     190.0       2851.0    14255.0  12.143056
# 8830    8830   977.0     971.0     194.0       2922.0    14610.0  12.438889
# 6225    6225   979.0     954.0     193.0       2899.0    14495.0  12.345833
# 6688    6688   976.0     967.0     194.0       2914.0    14570.0  12.409722
# 5864    5864   978.0     956.0     193.0       2901.0    14505.0  12.352778
# 8266    8266   996.0     871.0     186.0       2800.0    14000.0  11.920833
# 7555    7555   973.0     964.0     193.0       2905.0    14525.0  12.368056
# 3407    3407   986.0     904.0     189.0       2835.0    14175.0  12.075000
#
#       age  gender         clan  rank
# 8594   23  Female         News   1.0
# 3284   21  Female        Music   2.0
# 3699   29  Female    Bollywood   3.5
# 8274   28  Female      Fashion   3.5
# 7286   48    Male       Travel   5.5
# 2249   38    Male         Jobs   5.5
# 1538   33  Female  Internships   7.0
# 6609   26  Female     Trending   8.0
# 9303   41  Female         Jobs   9.0
# 2649   34    Male    Bollywood  10.0
# 2200   43    Male        Music  11.0
# 8126   35  Female    Bollywood  12.0
# 5515   45  Female     Politics  13.0
# 8830   41  Female    Bollywood  14.0
# 6225   37    Male  Internships  15.5
# 6688   33  Female    Bollywood  15.5
# 5864   45  Female    Bollywood  17.0
# 8266   44  Female         News  18.0
# 7555   49  Female   Technology  19.0
# 3407   40    Male         Food  20.0

# %% [markdown]
# ### Bottom 20 posts

# %%
data.tail(10)
# Out:
#      User_ID  upvote  downvote  comments  impressions  followers  timespent  \
# 7794    7794    13.0      36.0       4.0         73.0      365.0   0.304167
# 3498    3498    17.0      14.0       3.0         46.0      230.0   0.195833
# 1370    1370     7.0      57.0       6.0         96.0      480.0   0.405556
# 1194    1194     3.0      71.0       7.0        111.0      555.0   0.469444
# 7403    7403     6.0      50.0       5.0         84.0      420.0   0.352778
# 4287    4287    10.0      31.0       4.0         61.0      305.0   0.259722
# 1642    1642     3.0      59.0       6.0         93.0      465.0   0.394444
# 9609    9609     7.0      28.0       3.0         52.0      260.0   0.218056
# 4307    4307     1.0      45.0       4.0         69.0      345.0   0.288889
# 188      188     6.0      18.0       2.0         36.0      180.0   0.150000
#
#       age  gender         clan     rank
# 7794   41    Male  Internships   9991.0
# 3498   36  Female     Startups   9992.5
# 1370   33  Female         News   9992.5
# 1194   28  Female        Music   9994.0
# 7403   39    Male     Startups   9995.0
# 4287   33    Male     Trending   9996.0
# 1642   31  Female    Bollywood   9997.0
# 9609   24    Male     Trending   9998.0
# 4307   27  Female         Jobs   9999.0
# 188    21    Male         Food  10000.0

# %% [markdown]
# ### With this method we can Rank the users post and whenever a person logged into his account he can see the post based on Rank

# %%
data.to_csv("Revidly_Analytics.csv",index=False)

# %% [markdown]
# #### I also did this project in excel where you need to enter just the upvote and downvote of a particular post ( and also some user information like gender , clan , age) after that it will automatically fetch you results for other columns like comments, impressions , followers , timespent on particular post , Rank Value ,Rank
